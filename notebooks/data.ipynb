# %%
pip install soccerdata
# Out:
# ...
#   Using cached soccerdata-1.5.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached lxml-4.9.4.tar.gz (3.6 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached undetected_chromedriver-3.5.5-py3-none-any.whl
# ...
#   Using cached unicode-2.9-py2.py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached selenium-4.39.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# ...
#   Using cached trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
from soccerdata import FBref
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from soccerdata import FBref
#
# ModuleNotFoundError: No module named 'soccerdata'
